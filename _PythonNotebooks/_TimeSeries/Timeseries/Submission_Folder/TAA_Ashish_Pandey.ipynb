# %%
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

# %%
df =  pd.read_csv("AirPassengers.csv", index_col=0)
df.head()
# Out:
#          #Passengers
# Month
# 1949-01          112
# 1949-02          118
# 1949-03          132
# 1949-04          129
# 1949-05          121

# %%
df.index.min()
# Out:
# '1949-01'

# %%
df.index.max()
# Out:
# '1960-12'

# %%
df.index
# Out:
# Index(['1949-01', '1949-02', '1949-03', '1949-04', '1949-05', '1949-06',
#        '1949-07', '1949-08', '1949-09', '1949-10',
#        ...
#        '1960-03', '1960-04', '1960-05', '1960-06', '1960-07', '1960-08',
#        '1960-09', '1960-10', '1960-11', '1960-12'],
#       dtype='object', name='Month', length=144)

# %%
df.index = pd.to_datetime(df.index)

# %%
df.index
# Out:
# DatetimeIndex(['1949-01-01', '1949-02-01', '1949-03-01', '1949-04-01',
#                '1949-05-01', '1949-06-01', '1949-07-01', '1949-08-01',
#                '1949-09-01', '1949-10-01',
#                ...
#                '1960-03-01', '1960-04-01', '1960-05-01', '1960-06-01',
#                '1960-07-01', '1960-08-01', '1960-09-01', '1960-10-01',
#                '1960-11-01', '1960-12-01'],
#               dtype='datetime64[ns]', name='Month', length=144, freq=None)

# %%
df.plot(figsize = (15,6))
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
from matplotlib.pyplot import rcParams
rcParams['figure.figsize'] = 18,8
decomposition = sm.tsa.seasonal_decompose(df, model = "additive")
fig = decomposition.plot()

# %%
from matplotlib.pyplot import rcParams
rcParams['figure.figsize'] = 18,8
decomposition = sm.tsa.seasonal_decompose(df, model = "multiplicative")
fig = decomposition.plot()

# %%
df_ma = df.copy()

# %%
df_ma['SMA_4'] = df_ma.rolling(window = 4).mean()
df_ma.head(20)
# Out:
#             #Passengers   SMA_4
# Month
# 1949-01-01          112     NaN
# 1949-02-01          118     NaN
# 1949-03-01          132     NaN
# 1949-04-01          129  122.75
# 1949-05-01          121  125.00
# 1949-06-01          135  129.25
# 1949-07-01          148  133.25
# 1949-08-01          148  138.00
# 1949-09-01          136  141.75
# 1949-10-01          119  137.75
# 1949-11-01          104  126.75
# 1949-12-01          118  119.25
# 1950-01-01          115  114.00
# 1950-02-01          126  115.75
# 1950-03-01          141  125.00
# 1950-04-01          135  129.25
# 1950-05-01          125  131.75
# 1950-06-01          149  137.50
# 1950-07-01          170  144.75
# 1950-08-01          170  153.50

# %%
plt.plot(df_ma['#Passengers'], label = 'Original Data')
plt.plot(df_ma['SMA_4'], label = "SMA 4 Model")
plt.legend()

# %%
df_ma_8 = df.copy()

# %%
df_ma['SMA_8'] = df_ma_8.rolling(window = 8).mean()
df_ma.head(20)
# Out:
#             #Passengers   SMA_4    SMA_8
# Month
# 1949-01-01          112     NaN      NaN
# 1949-02-01          118     NaN      NaN
# 1949-03-01          132     NaN      NaN
# 1949-04-01          129  122.75      NaN
# 1949-05-01          121  125.00      NaN
# 1949-06-01          135  129.25      NaN
# 1949-07-01          148  133.25      NaN
# 1949-08-01          148  138.00  130.375
# 1949-09-01          136  141.75  133.375
# 1949-10-01          119  137.75  133.500
# 1949-11-01          104  126.75  130.000
# 1949-12-01          118  119.25  128.625
# 1950-01-01          115  114.00  127.875
# 1950-02-01          126  115.75  126.750
# 1950-03-01          141  125.00  125.875
# 1950-04-01          135  129.25  124.250
# 1950-05-01          125  131.75  122.875
# 1950-06-01          149  137.50  126.625
# 1950-07-01          170  144.75  134.875
# 1950-08-01          170  153.50  141.375

# %%
plt.plot(df_ma['#Passengers'], label = 'Original Data')
plt.plot(df_ma['SMA_8'], label = "SMA 8 Model")
plt.legend()

# %%
df_ma_12 = df.copy()

# %%
df_ma['SMA_12'] = df_ma_12.rolling(window = 12).mean()
df_ma.head(20)
# Out:
#             #Passengers   SMA_4    SMA_8      SMA_12
# Month
# 1949-01-01          112     NaN      NaN         NaN
# 1949-02-01          118     NaN      NaN         NaN
# 1949-03-01          132     NaN      NaN         NaN
# 1949-04-01          129  122.75      NaN         NaN
# 1949-05-01          121  125.00      NaN         NaN
# 1949-06-01          135  129.25      NaN         NaN
# 1949-07-01          148  133.25      NaN         NaN
# 1949-08-01          148  138.00  130.375         NaN
# 1949-09-01          136  141.75  133.375         NaN
# 1949-10-01          119  137.75  133.500         NaN
# 1949-11-01          104  126.75  130.000         NaN
# 1949-12-01          118  119.25  128.625  126.666667
# 1950-01-01          115  114.00  127.875  126.916667
# 1950-02-01          126  115.75  126.750  127.583333
# 1950-03-01          141  125.00  125.875  128.333333
# 1950-04-01          135  129.25  124.250  128.833333
# 1950-05-01          125  131.75  122.875  129.166667
# 1950-06-01          149  137.50  126.625  130.333333
# 1950-07-01          170  144.75  134.875  132.166667
# 1950-08-01          170  153.50  141.375  134.000000

# %%
plt.plot(df_ma['#Passengers'], label = 'Original Data')
plt.plot(df_ma['SMA_12'], label = "SMA 12 Model")
plt.legend()

# %%
plt.plot(df_ma['#Passengers'], label = 'Original Data')
plt.plot(df_ma['SMA_4'], label = "SMA 4 Model")
plt.plot(df_ma['SMA_8'], label = "SMA 8 Model")
plt.plot(df_ma['SMA_12'], label = "SMA 12 Model")
plt.legend()

# %%
def mape(y_true, y_pred):
    return np.mean(np.abs((y_true-y_pred)/y_true)) *100

# %%
mape(df_ma['#Passengers'], df_ma['SMA_4'])
# Out:
# 9.187719963528176

# %%
mape(df_ma['#Passengers'], df_ma['SMA_8'])
# Out:
# 12.513798936616883

# %%
mape(df_ma['#Passengers'], df_ma['SMA_12'])
# Out:
# 10.778519137583197
